# %%
conda install pandas==0.25.1

# %%
pip install pandas

# %%
import pandas as pd

path="D:\Python\Programs\Practice\FL_insurance_sample.csv"
df=pd.read_csv(path)
print(df.head())
x=df[['policyID']]
print(x)
print(df.iloc[0,'policyID'])

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = read_csv("import-85.data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9841b4ead51b> in <module>
# ----> 1 df = read_csv("import-85.data")
#
# NameError: name 'read_csv' is not defined

# %%
df = pd.read_csv("imports-85.data")

# %%
df = pd.read_csv("imports-85.data")

# %%
df.head()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
h = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df.columns = h

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df['symboling'] = df['symboling'] + 1

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          4                 ?  alfa-romero       gas        std          two
# 1          2                 ?  alfa-romero       gas        std          two
# 2          3               164         audi       gas        std         four
# 3          3               164         audi       gas        std         four
# 4          3                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
x = d[['normalized-losses']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-1f27e7b7c2ae> in <module>
# ----> 1 x = d[['normalized-losses']]
#
# NameError: name 'd' is not defined

# %%
x = df[['normalized-losses']]

# %%
x
# Out:
#     normalized-losses
# 0                   ?
# 1                   ?
# 2                 164
# 3                 164
# 4                   ?
# ..                ...
# 199                95
# 200                95
# 201                95
# 202                95
# 203                95
#
# [204 rows x 1 columns]

# %%
df.head(200)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            4                 ?  alfa-romero       gas        std
# 1            2                 ?  alfa-romero       gas        std
# 2            3               164         audi       gas        std
# 3            3               164         audi       gas        std
# 4            3                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 195         -1               103        volvo       gas        std
# 196          0                74        volvo       gas        std
# 197         -1               103        volvo       gas      turbo
# 198          0                74        volvo       gas      turbo
# 199          0                95        volvo       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
x.head(200)
# Out:
#     normalized-losses
# 0                   ?
# 1                   ?
# 2                 164
# 3                 164
# 4                   ?
# ..                ...
# 195               103
# 196                74
# 197               103
# 198                74
# 199                95
#
# [200 rows x 1 columns]

# %%
df['normalized-losses'].dtype
# Out:
# dtype('O')

# %%
df['normalized-losses'].type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-efbbed102013> in <module>
# ----> 1 df['normalized-losses'].type
#
# c:\users\yerra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'type'

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          4                 ?  alfa-romero       gas        std          two
# 1          2                 ?  alfa-romero       gas        std          two
# 2          3               164         audi       gas        std         four
# 3          3               164         audi       gas        std         four
# 4          3                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
import numpy as np
df.replace("?",np.nan,inplace = True)

# %%
k = df['normalized-losses'].astype("float").mean(axis=0)

# %%
k
# Out:
# 122.0

# %%
missing = df.isnull()

# %%
missing
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False               True  False      False       False         False
# 1        False               True  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False               True  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 199      False              False  False      False       False         False
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
#
# ...

# %%
for i in missing.columns.values.tolist():
    print(i)
    print(missing[i].value_counts())
    print("")
# Out:
# symboling
# False    204
# Name: symboling, dtype: int64
#
# normalized-losses
# False    164
# True      40
# Name: normalized-losses, dtype: int64
#
# make
# False    204
# Name: make, dtype: int64
#
# fuel-type
# False    204
# Name: fuel-type, dtype: int64
#
# aspiration
# False    204
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    202
# True       2
# Name: num-of-doors, dtype: int64
#
# body-style
# False    204
# Name: body-style, dtype: int64
#
# drive-wheels
# False    204
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    204
# Name: engine-location, dtype: int64
#
# wheel-base
# False    204
# Name: wheel-base, dtype: int64
#
# length
# False    204
# Name: length, dtype: int64
#
# width
# False    204
# Name: width, dtype: int64
#
# height
# False    204
# Name: height, dtype: int64
#
# curb-weight
# False    204
# Name: curb-weight, dtype: int64
#
# engine-type
# False    204
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# ...

# %%
df.__dict__
# Out:
# {'_is_copy': None,
#  '_data': BlockManager
#  Items: Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#         'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#         'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#         'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#         'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#         'highway-mpg', 'price'],
#        dtype='object')
#  Axis 1: RangeIndex(start=0, stop=204, step=1)
#  FloatBlock: [9, 10, 11, 12, 20], 5 x 204, dtype: float64
#  IntBlock: [0, 13, 16, 23, 24], 5 x 204, dtype: int64
#  ObjectBlock: [1, 2, 3, 4, 5, 6, 7, 8, 14, 15, 17, 18, 19, 21, 22, 25], 16 x 204, dtype: object,
#  '_item_cache': {'normalized-losses': 0      NaN
#   1      NaN
#   2      164
#   3      164
#   4      NaN
#         ...
#   199     95
#   200     95
#   201     95
#   202     95
#   203     95
# ...

# %%
df.items
# Out:
# <bound method DataFrame.items of      symboling normalized-losses         make fuel-type aspiration  \
# 0            4               NaN  alfa-romero       gas        std
# 1            2               NaN  alfa-romero       gas        std
# 2            3               164         audi       gas        std
# 3            3               164         audi       gas        std
# 4            3               NaN         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199          0                95        volvo       gas        std
# 200          0                95        volvo       gas      turbo
# 201          0                95        volvo       gas        std
# 202          0                95        volvo    diesel      turbo
# 203          0                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      symboling normalized-losses         make fuel-type aspiration  \
# 0            4               NaN  alfa-romero       gas        std
# 1            2               NaN  alfa-romero       gas        std
# 2            3               164         audi       gas        std
# 3            3               164         audi       gas        std
# 4            3               NaN         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199          0                95        volvo       gas        std
# 200          0                95        volvo       gas      turbo
# 201          0                95        volvo       gas        std
# 202          0                95        volvo    diesel      turbo
# 203          0                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     1.823529   98.806373  174.075000   65.916667   53.749020
# std      1.239035    5.994144   12.362123    2.146716    2.424901
# min     -1.000000   86.600000  141.100000   60.300000   47.800000
# 25%      1.000000   94.500000  166.300000   64.075000   52.000000
# 50%      2.000000   97.000000  173.200000   65.500000   54.100000
# 75%      3.000000  102.400000  183.200000   66.900000   55.500000
# max      4.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   204.000000   204.000000         204.000000  204.000000   204.000000
# mean   2555.602941   126.892157          10.148137   25.240196    30.769608
# std     521.960820    41.744569           3.981000    6.551513     6.898337
# ...

# %%
df.describe(include="all")
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   204.000000               164     204       204        204
# unique         NaN                51      22         2          2
# top            NaN               161  toyota       gas        std
# freq           NaN                11      32       184        167
# mean      1.823529               NaN     NaN       NaN        NaN
# std       1.239035               NaN     NaN       NaN        NaN
# min      -1.000000               NaN     NaN       NaN        NaN
# 25%       1.000000               NaN     NaN       NaN        NaN
# 50%       2.000000               NaN     NaN       NaN        NaN
# 75%       3.000000               NaN     NaN       NaN        NaN
# max       4.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           202        204          204             204  204.000000  ...
# ...

# %%
k = df['normalized-losses'].astype("float").mean(axis=0)

# %%
k
# Out:
# 122.0

# %%
df['normalized-losses'].replace(np.nan,k,inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            4               122  alfa-romero       gas        std
# 1            2               122  alfa-romero       gas        std
# 2            3               164         audi       gas        std
# 3            3               164         audi       gas        std
# 4            3               122         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199          0                95        volvo       gas        std
# 200          0                95        volvo       gas      turbo
# 201          0                95        volvo       gas        std
# 202          0                95        volvo    diesel      turbo
# 203          0                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df['price'].isnull().value_counts()
# Out:
# False    200
# True       4
# Name: price, dtype: int64

# %%
df.dropna(subset=["price"],axis = 0,inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            4               122  alfa-romero       gas        std
# 1            2               122  alfa-romero       gas        std
# 2            3               164         audi       gas        std
# 3            3               164         audi       gas        std
# 4            3               122         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199          0                95        volvo       gas        std
# 200          0                95        volvo       gas      turbo
# 201          0                95        volvo       gas        std
# 202          0                95        volvo    diesel      turbo
# 203          0                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            4               122  alfa-romero       gas        std
# 1            2               122  alfa-romero       gas        std
# 2            3               164         audi       gas        std
# 3            3               164         audi       gas        std
# 4            3               122         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 195          0                95        volvo       gas        std
# 196          0                95        volvo       gas      turbo
# 197          0                95        volvo       gas        std
# 198          0                95        volvo    diesel      turbo
# 199          0                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-09616d73ed79> in <module>
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-b959c06452a1> in <module>
# ----> 1 df.dtype
#
# c:\users\yerra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df[['normalized-loses','stroke','bore']] = df[['normalized-loses','stroke','bore']].astype('float')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-2d83174a6eb0> in <module>
# ----> 1 df[['normalized-loses','stroke','bore']] = df[['normalized-loses','stroke','bore']].astype('float')
#
# c:\users\yerra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# c:\users\yerra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1549             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1550
# -> 1551         self._validate_read_indexer(
# ...

# %%
df[['normalized-losses','stroke','bore']] = df[['normalized-losses','stroke','bore']].astype('float')

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df[['num-of-doors']] = df[['num-of-doors']].astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-de37799cc5ef> in <module>
# ----> 1 df[['num-of-doors']] = df[['num-of-doors']].astype("int")
#
# c:\users\yerra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# c:\users\yerra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
# ...

# %%
df['drive-wheels']
# Out:
# 0      rwd
# 1      rwd
# 2      fwd
# 3      4wd
# 4      fwd
#       ...
# 195    rwd
# 196    rwd
# 197    rwd
# 198    rwd
# 199    rwd
# Name: drive-wheels, Length: 200, dtype: object

# %%
df['num-of-cylinders']
# Out:
# 0      four
# 1       six
# 2      four
# 3      five
# 4      five
#        ...
# 195    four
# 196    four
# 197     six
# 198     six
# 199    four
# Name: num-of-cylinders, Length: 200, dtype: object

# %%
df[['horsepower','price',"peak-rpm"]]  = df[['horsepower','price',"peak-rpm"]].astype("float")

# %%
df['price'].std
# Out:
# <bound method Series.std of 0      16500.0
# 1      16500.0
# 2      13950.0
# 3      17450.0
# 4      15250.0
#         ...
# 195    16845.0
# 196    19045.0
# 197    21485.0
# 198    22470.0
# 199    22625.0
# Name: price, Length: 200, dtype: float64>

# %%
df['price'].std()
# Out:
# 7966.98255798872

# %%
std = df[['price']].std()

# %%
mean = df['price'].mean()

# %%
std
# Out:
# price    7966.982558
# dtype: float64

# %%
mean
# Out:
# 13205.69

# %%
k =mean/std

# %%
k
# Out:
# price    1.657552
# dtype: float64

# %%
bins =np.linspace(df['horsepower'].min(),df['horsepower'].max(),4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
df['new_hp'] = pd.cut(df['horsepower'],bins,labels=['low','med','high'],include_lowest=True)
df[['new_hp','horsepower']]
# Out:
#     new_hp  horsepower
# 0      low       111.0
# 1      med       154.0
# 2      low       102.0
# 3      low       115.0
# 4      low       110.0
# ..     ...         ...
# 195    low       114.0
# 196    med       160.0
# 197    med       134.0
# 198    low       106.0
# 199    low       114.0
#
# [200 rows x 2 columns]

# %%
new_hp
# Out:
# 0      low
# 1      med
# 2      low
# 3      low
# 4      low
#       ...
# 195    low
# 196    med
# 197    med
# 198    low
# 199    low
# Name: horsepower, Length: 200, dtype: category
# Categories (3, object): [low < med < high]

# %%
df['new_hp'].value_counts()
# Out:
# low     150
# med      43
# high      5
# Name: new_hp, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
a = (0,1,2)
plt.pyplot.hist(df['horsepower'],bins=3)
group = ['low','med','high']
#pyplot.bar(group,df['new_hp'].value_counts())

# %%
df.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-986e25863b45> in <module>
# ----> 1 df.value_counts()
#
# c:\users\yerra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
df['new_hp'].value_counts()
# Out:
# low     150
# med      43
# high      5
# Name: new_hp, dtype: int64

# %%
new_hp
# Out:
# 0      low
# 1      med
# 2      low
# 3      low
# 4      low
#       ...
# 195    low
# 196    med
# 197    med
# 198    low
# 199    low
# Name: horsepower, Length: 200, dtype: category
# Categories (3, object): [low < med < high]

# %%
new_hp.index.name = hp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-118-34ee57e495d2> in <module>
# ----> 1 new_hp.index.name = hp
#
# NameError: name 'hp' is not defined

# %%
new_hp = df.rename(columns = {"hpp":"hp"},inplace=True)

# %%
new_hp

# %%
hpp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-123-f84210c964fa> in <module>
# ----> 1 hpp
#
# NameError: name 'hpp' is not defined

# %%
hp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-124-0af546e15d3e> in <module>
# ----> 1 hp
#
# NameError: name 'hp' is not defined

# %%
new_hp.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-78885820366d> in <module>
# ----> 1 new_hp.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
new_hp.index.name = "hp"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-f9d7e3cb03be> in <module>
# ----> 1 new_hp.index.name = "hp"
#
# AttributeError: 'NoneType' object has no attribute 'index'

# %%
hp = df['']
